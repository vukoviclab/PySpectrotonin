# %%
from visualizing import *
from data_prepration import *
from scatter_plot import *

# %%
import matplotlib
print(matplotlib.get_cachedir())
# Out:
# /home/payam/.cache/matplotlib

# %%
# !pwd
# Out:
# /data1/payam/ai/seroto/final_main

# %%
# threshold_format_list,threshold_list = process_wave_data(rerun=True)

# %%
threshold_format_list,threshold_list = process_wave_data()[0],process_wave_data()[1]

# %%
visualize_data(experimental_dataframe='exp_result.csv', threshold_list=threshold_format_list, plot_kind='heatmap', 
                   colormap=None, difference=None, top_n=None)
# Out:
# /data1/payam/ai/seroto/final_main/visualizing.py:171: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(pad=0)

# %%
# visualize_data(experimental_dataframe='exp_result.csv', threshold_list=threshold_format_list, plot_kind='violin', 
#                    colormap=None, difference=None, top_n=None)

# %%
# visualize_data(experimental_dataframe='exp_result.csv', threshold_list=threshold_format_list, plot_kind='boxplot', 
#                    colormap=None, difference=True, top_n=None)

# %%
# visualize_data(experimental_dataframe='exp_result.csv', threshold_list=threshold_format_list, plot_kind='heatmap', 
#                    colormap=None, difference=None, top_n=None)
# visualize_data(experimental_dataframe='exp_result.csv', threshold_list=threshold_format_list, plot_kind='heatmap', 
#                    colormap=None, difference=None, top_n=10)
# visualize_data(experimental_dataframe='exp_result.csv', threshold_list=threshold_format_list, plot_kind='violin', 
#                    colormap=None, difference=None, top_n=None)
# visualize_data(experimental_dataframe='exp_result.csv', threshold_list=threshold_format_list, plot_kind='violin', 
#                    colormap=None, difference=None, top_n=10)
# visualize_data(experimental_dataframe='exp_result.csv', threshold_list=threshold_format_list, plot_kind='boxplot', 
#                    colormap=None, difference=None, top_n=None)
# visualize_data(experimental_dataframe='exp_result.csv', threshold_list=threshold_format_list, plot_kind='boxplot', 
#                    colormap=None, difference=None, top_n=10)
# visualize_data(experimental_dataframe='exp_result.csv', threshold_list=threshold_format_list, plot_kind='boxplot', 
#                    colormap=None, difference=True, top_n=None)
# # scatter_plot(threshold_list)

# %%
# import pandas as pd

# # Sample Series
# s = pd.Series([
#     [0.27801130689554765, 0.3226666164523117, 0.18],
#     [0.11764606971890251, -0.015538746210643883, 0.2],
#     [-0.1361975669976902, -0.09544784189030198, 0.3],
#     [-0.1343648592093224, 0.17957663635196985, 0.4],
#     [-0.08831597577059891, -0.2239357856665976, 0.5],
#     [-0.3502853658628659, -0.08656489577269466, 0.6]
# ])

# # Convert the Series to a DataFrame with each row as a column
# df = pd.DataFrame(s.tolist()).T

# # Rename the columns
# df.columns = [f"S{i+1}" for i in range(df.shape[1])]

# df

# %%
# visualize_data(experimental_dataframe='exp_result.csv', threshold_list=threshold_format_list, plot_kind='heatmap', 
#                    colormap=None, difference=None, top_n=None)
